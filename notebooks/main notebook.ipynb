# %%
import chess.pgn
import pandas as pd

# Initialize empty lists for each column of the dataframe
white_elo_list = []
black_elo_list = []
white_result_list = []
black_result_list = []

# Initialize empty lists for each move of the game
white_moves = []
black_moves = []
for i in range(100):
    white_moves.append([])
    black_moves.append([])

# Open the PGN file
with open("../data/Magnus_Carlsen1.pgn") as f:
    # Loop over all games in the file
    while True:
        # Read the next game
        game = chess.pgn.read_game(f)
        if game is None:
            break

        # Extract information about the game
        headers = game.headers
        white = headers["White"]
        black = headers["Black"]
        white_elo = int(headers["WhiteElo"])
        black_elo = int(headers["BlackElo"])
        result = headers["Result"]
        
        # Extract the result components
        if result == "1-0":
            white_result = 1
            black_result = 0
        elif result == "0-1":
            white_result = 0
            black_result = 1
        else:
            white_result = 0
            black_result = 0

        # Play through the moves of the game
        node = game
        white_moves_counter = 0
        black_moves_counter = 0
        while not node.is_end():
            node = node.variations[0]
            if node.board().turn == chess.WHITE:
                white_moves[white_moves_counter].append(str(node.move))
                white_moves_counter += 1
            else:
                black_moves[black_moves_counter].append(str(node.move))
                black_moves_counter += 1

        # Append the information for the game to the lists
        white_elo_list.append(white_elo)
        black_elo_list.append(black_elo)
        white_result_list.append(white_result)
        black_result_list.append(black_result)

# Create a dataframe from the lists
df = pd.DataFrame({
    'White Elo': white_elo_list,
    'Black Elo': black_elo_list,
    'White Result': white_result_list,
    'Black Result': black_result_list
})

# Add the columns for the moves
moves_columns = {}
for i in range(100):
    moves_columns[f'White Move {i+1}'] = pd.Series(black_moves[i], dtype=object)
    moves_columns[f'Black Move {i+1}'] = pd.Series(white_moves[i], dtype=object)
df = pd.concat([df, pd.DataFrame(moves_columns)], axis=1)

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#     White Elo  Black Elo  White Result  Black Result White Move 1  \
# 0        2864       2761             1             0         d2d4
# 1        2832       2813             1             0         d2d4
# 2        2864       2751             1             0         g1f3
# 3        2864       2744             1             0         d2d4
# 4        2864       2753             1             0         d2d4
# 5        2864       2518             1             0         g1f3
# 6        2864       2613             1             0         e2e4
# 7        2859       2632             0             1         b2b3
# 8        2859       2605             1             0         a2a4
# 9        2859       2692             1             0         e2e4
# 10       2859       2620             1             0         b2b3
# 11       2859       2450             1             0         d2d4
# 12       2859       2441             1             0         e2e4
# ...
